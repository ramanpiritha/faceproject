# %% [markdown]
# ## Face-Detection-with-Haar-Cascades
# # NAME:PIRITHARAMAN R
# # REG NO:212223230148

# %% [markdown]
# ## Face Detecetion

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('image_01.png',0)
img=cv2.resize(img,(600,400))
plt.imshow(img,cmap='gray')

# %%
img2=cv2.imread('image_02.png',0)
img2=cv2.resize(img2,(600,400))
plt.imshow(img2,cmap='gray')

# %%
img3=cv2.imread('image_03.png',0)
img3=cv2.resize(img3,(600,400))
plt.imshow(img3,cmap='gray')

# %%
plt.figure(figsize=(20,12))
plt.subplot(131)
plt.imshow(img,cmap='gray')
plt.subplot(132)
plt.imshow(img2,cmap='gray')
plt.subplot(133)
plt.imshow(img3,cmap='gray')

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    face_img=img.copy()
    face_rects=face_cascade.detectMultiScale(face_img)
    for (x,y,w,h) in face_rects:
        cv2.rectangle(face_img,(x,y),(x+w,y+h),(127,0,255),10)
        cv2.imshow('Face detection',face_img)
    return face_img

# %%
eye_cascade=cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
def detect_eye(img):
    eye_img=img.copy()
    eye_rects=eye_cascade.detectMultiScale(eye_img)
    for (x,y,w,h) in eye_rects:
        cv2.rectangle(eye_img,(x,y),(x+w,y+h),(127,0,255),10)
        cv2.imshow('Face detection',eye_img)
    return eye_img

# %%
detect_img1=detect_face(img)
detect_img2=detect_face(img2)
detect_img3=detect_face(img3)

# %%
plt.figure(figsize=(20,12))
plt.subplot(131)
plt.imshow(detect_img1,cmap='gray')
plt.subplot(132)
plt.imshow(detect_img2,cmap='gray')
plt.subplot(133)
plt.imshow(detect_img3,cmap='gray')

# %%
detect_img4=detect_eye(img)
detect_img5=detect_eye(img2)
detect_img6=detect_eye(img3)

# %%
plt.figure(figsize=(20,12))
plt.subplot(131)
plt.imshow(detect_img4,cmap='gray')
plt.subplot(132)
plt.imshow(detect_img5,cmap='gray')
plt.subplot(133)
plt.imshow(detect_img6,cmap='gray')

# %%
cap = cv2.VideoCapture(0)
plt.ion()
fig, ax=plt.subplots()

ret, frame=cap.read(0)
frame=detect_face(frame)
im=ax.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.title('Video Face Detection')

while True:
    ret, frame=cap.read(0)
    frame=detect_face(frame)
    
    #Update matplotlib image
    im.set_data(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    plt.pause(0.10)
cap.release()
plt.close()
